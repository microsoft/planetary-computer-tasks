# %%
from pathlib import Path
import json
import pandas as pd

# %%
from pathlib import Path
import json

# Define base datasets path
datasets_path = Path(".")

# Find all config.json files inside any 'collection/*/' subdirectory
config_paths = list(datasets_path.rglob("collection/*/config.json"))

# Collect valid collection IDs based on folder names
valid_collection_ids = {path.parent.name for path in config_paths}

# Load each config.json and annotate with its collection_id
configs = []
for path in config_paths:
    try:
        with path.open("r") as f:
            config_data = json.load(f)
        config_data["collection_id"] = path.parent.name
        configs.append(config_data)
    except Exception as e:
        print(f"Error loading {path}: {e}")

print(f"Loaded {len(configs)} config.json files.")
# Out:
# Loaded 47 config.json files.

# %%
all_cql_mosaics = [
    mosaic['cql']
    for config in configs
    if 'mosaic_info' in config and 'mosaics' in config['mosaic_info']
    for mosaic in config['mosaic_info']['mosaics']
    if mosaic.get('cql')  # skips if 'cql' is empty list or missing
]

# %% [markdown]
# Only 4 properties are used for searches defined as 'mosaics' in Planetary Computer

# %%
from collections import Counter

def extract_properties(cql_expr):
    """Recursively extract all 'property' values from a CQL expression."""
    properties = []
    if isinstance(cql_expr, dict):
        for v in cql_expr.values():
            properties += extract_properties(v)
        if 'property' in cql_expr:
            properties.append(cql_expr['property'])
    elif isinstance(cql_expr, list):
        for item in cql_expr:
            properties += extract_properties(item)
    return properties

# Flatten list of all cql expressions (each is a list of expressions)
property_counter = Counter()
for cql_list in all_cql_mosaics:
    for expr in cql_list:
        props = extract_properties(expr)
        property_counter.update(props)

# Show results
for prop, count in property_counter.most_common():
    print(f"{prop}: {count}")
# Out:
# datetime: 101
# eo:cloud_cover: 30
# noaa_climate_normals:frequency: 11
# noaa_climate_normals:period: 11

# %%
from collections import Counter

# Track all top-level keys used inside any CQL expression
cql_keys = Counter()

for config in configs:
    mosaics = config.get('mosaic_info', {}).get('mosaics', [])
    for mosaic in mosaics:
        for expr in mosaic.get('cql', []):
            if isinstance(expr, dict):
                cql_keys.update(expr.keys())

# Display results
print("CQL keys used across all mosaics:")
for key, count in cql_keys.most_common():
    print(f"  {key}: {count}")
# Out:
# CQL keys used across all mosaics:
#   op: 153
#   args: 153

# %% [markdown]
# Every collection has a mosaic_info and render_config in config.json

# %%
all_key_sets = [set(config.keys()) for config in configs]
all_keys = set().union(*all_key_sets)
print(all_keys)
# Out:
# {'collection_id', 'mosaic_info', 'render_config'}

# %%
all_mosaic_info_key_sets = [set(config.get('mosaic_info',{}).keys()) for config in configs]
all_mosaic_info_keys = set().union(*all_mosaic_info_key_sets)
print(all_mosaic_info_keys)
# Out:
# {'animation_hint', 'default_custom_query', 'mosaics', 'default_location', 'render_options'}

# %%
all_mosaic_key_sets = [
    set(mosaic.keys())
    for config in configs
    for mosaic in config.get('mosaic_info',{}).get('mosaics',[])
    ]

mosaic_key_union = set().union(*all_mosaic_key_sets)

print(mosaic_key_union)
# Out:
# {'name', 'description', 'cql'}

# %%
all_mosaics = [
    {**mosaic, "collection_id": config['collection_id']}
    for config in configs
    for mosaic in config.get('mosaic_info',{}).get('mosaics',[])
]

all_mosaics_df = pd.DataFrame(all_mosaics)

# %% [markdown]
# Commonly, a mosaic includes a cql search based on the properties of datetime, eo:cloud_cover, id, sar:polarizations, or usda_cdl:type

# %%
from collections import Counter

set(all_mosaics_df['cql'].explode().dropna().apply(lambda x: x.get('args')[0]).apply(str))
# Out:
# {"{'property': 'datetime'}",
#  "{'property': 'eo:cloud_cover'}",
#  "{'property': 'id'}",
#  "{'property': 'sar:polarizations'}",
#  "{'property': 'usda_cdl:type'}"}

# %%
list(all_mosaics_df.apply(lambda x: x.to_dict() if (('sentinel' not in x['collection_id']) and ('datetime' in str(x['cql']))) else None, axis=1).dropna())
# Out:
# [{'name': '2020',
#   'description': '2020 Biodiversity Intactness',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2020-01-01T00:00:00Z', '2020-12-31T23:59:59Z']}]}],
#   'collection_id': 'io-biodiversity'},
#  {'name': '2019',
#   'description': '2019 Biodiversity Intactness',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2019-01-01T00:00:00Z', '2019-12-31T23:59:59Z']}]}],
#   'collection_id': 'io-biodiversity'},
#  {'name': '2018',
#   'description': '2018 Biodiversity Intactness',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2018-01-01T00:00:00Z', '2018-12-31T23:59:59Z']}]}],
#   'collection_id': 'io-biodiversity'},
#  {'name': '2017',
#   'description': '2017 Biodiversity Intactness',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2017-01-01T00:00:00Z', '2017-12-31T23:59:59Z']}]}],
#   'collection_id': 'io-biodiversity'},
#  {'name': 'Most recent',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2016-12-07T00:00:00Z', '2016-12-07T23:59:59Z']}]}],
#   'collection_id': 'alos-dem'},
#  {'name': '2019',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2018-08-01', '2019-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2018',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2017-08-01', '2018-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2017',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2016-08-01', '2017-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2016',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2015-08-01', '2016-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2015',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2014-08-01', '2015-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2014',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2013-08-01', '2014-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2013',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2012-08-01', '2013-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2012',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2011-08-01', '2012-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2011',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2010-08-01', '2011-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2010',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2009-08-01', '2010-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2009',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2008-08-01', '2009-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2008',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2007-08-01', '2008-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2007',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2006-08-01', '2007-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2006',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2005-08-01', '2006-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2005',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2004-08-01', '2005-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2004',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2003-08-01', '2004-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2003',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2002-08-01', '2003-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2023',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2023-01-01', '2023-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2022',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2022-01-01', '2022-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2021',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2021-01-01', '2021-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2020',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2020-01-01', '2020-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2019',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2019-01-01', '2019-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2018',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2018-01-01', '2018-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2017',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2017-01-01', '2017-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2016',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2016-01-01', '2016-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2015',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2015-01-01', '2015-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2014',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2014-01-01', '2014-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2013',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2013-01-01', '2013-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2012',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2012-01-01', '2012-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2011',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2011-01-01', '2011-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2010',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2010-01-01', '2010-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': 'Most recent',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2020-06-06T00:00:00Z', '2020-06-06T23:59:59Z']}]}],
#   'collection_id': 'jrc-gsw'},
#  {'name': 'Most recent (2020)',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2020-01-01', '2020-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2019',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2019-01-01', '2019-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2018',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2018-01-01', '2018-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2017',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2017-01-01', '2017-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2016',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2016-01-01', '2016-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2015',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2015-01-01', '2015-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2014',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2014-01-01', '2014-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2013',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2013-01-01', '2013-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2012',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2012-01-01', '2012-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2011',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2011-01-01', '2011-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2010',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2010-01-01', '2010-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2009',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2009-01-01', '2009-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2008',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2008-01-01', '2008-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2007',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2007-01-01', '2007-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2006',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2006-01-01', '2006-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2005',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2005-01-01', '2005-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2004',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2004-01-01', '2004-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2003',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2003-01-01', '2003-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2002',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2002-01-01', '2002-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2001',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2001-01-01', '2001-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2000',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2000-01-01', '2000-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '1999',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1999-01-01', '1999-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '1998',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1998-01-01', '1998-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '1997',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1997-01-01', '1997-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '1996',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1996-01-01', '1996-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '1995',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1995-01-01', '1995-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '1994',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1994-01-01', '1994-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '1993',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1993-01-01', '1993-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '1992',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1992-01-01', '1992-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2021 (version 2)',
#   'description': '2021 Land Cover',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2021-01-01T23:59:59Z', '2021-12-31T23:59:59Z']}]}],
#   'collection_id': 'esa-worldcover'},
#  {'name': '2020 (version 1)',
#   'description': '2020 Land Cover',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2020-01-01T23:59:59Z', '2020-12-31T23:59:59Z']}]}],
#   'collection_id': 'esa-worldcover'},
#  {'name': 'Most recent (2019)',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2019-01-01', '2019-12-31']}]}],
#   'collection_id': 'hrea'},
#  {'name': '2018',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2018-01-01', '2018-12-31']}]}],
#   'collection_id': 'hrea'},
#  {'name': '2017',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2017-01-01', '2017-12-31']}]}],
#   'collection_id': 'hrea'},
#  {'name': '2016',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2016-01-01', '2016-12-31']}]}],
#   'collection_id': 'hrea'},
#  {'name': '2015',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2015-01-01', '2015-12-31']}]}],
#   'collection_id': 'hrea'},
#  {'name': '2014',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2014-01-01', '2014-12-31']}]}],
#   'collection_id': 'hrea'},
#  {'name': '2013',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2013-01-01', '2013-12-31']}]}],
#   'collection_id': 'hrea'},
#  {'name': '2012',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2012-01-01', '2012-12-31']}]}],
#   'collection_id': 'hrea'},
#  {'name': 'Most recent',
#   'description': 'Most recent Land Use/Land Cover',
#   'cql': [{'op': '>=',
#     'args': [{'property': 'datetime'}, {'timestamp': '2015-01-01'}]}],
#   'collection_id': 'nrcan-landcover'},
#  {'name': 'All years',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1984-12-31', '2018-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': 'Most recent (2018)',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2018-01-01', '2018-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2017',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2017-01-01', '2017-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2016',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2016-01-01', '2016-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2015',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2015-01-01', '2015-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2014',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2014-01-01', '2014-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2013',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2013-01-01', '2013-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2012',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2012-01-01', '2012-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2011',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2011-01-01', '2011-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2010',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2010-01-01', '2010-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2009',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2009-01-01', '2009-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2008',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2008-01-01', '2008-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2007',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2007-01-01', '2007-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2006',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2006-01-01', '2006-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2005',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2005-01-01', '2005-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2004',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2004-01-01', '2004-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2003',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2003-01-01', '2003-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2002',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2002-01-01', '2002-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2001',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2001-01-01', '2001-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2000',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2000-01-01', '2000-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1999',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1999-01-01', '1999-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1998',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1998-01-01', '1998-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1997',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1997-01-01', '1997-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1996',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1996-01-01', '1996-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1995',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1995-01-01', '1995-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1994',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1994-01-01', '1994-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1993',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1993-01-01', '1993-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1992',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1992-01-01', '1992-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1991',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1991-01-01', '1991-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1990',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1990-01-01', '1990-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1989',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1989-01-01', '1989-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1988',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1988-01-01', '1988-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1987',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1987-01-01', '1987-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1986',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1986-01-01', '1986-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1985',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1985-01-01', '1985-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1984',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1984-12-31', '1984-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2020',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2020-01-01', '2020-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-palsar-mosaic'},
#  {'name': '2019',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2019-01-01', '2019-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-palsar-mosaic'},
#  {'name': '2018',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2018-01-01', '2018-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-palsar-mosaic'},
#  {'name': '2017',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2017-01-01', '2017-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-palsar-mosaic'},
#  {'name': '2016',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2016-01-01', '2016-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-palsar-mosaic'},
#  {'name': '2015',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2015-01-01', '2015-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-palsar-mosaic'},
#  {'name': '2020',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2020-01-01', '2020-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-fnf-mosaic'},
#  {'name': '2019',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2019-01-01', '2019-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-fnf-mosaic'},
#  {'name': '2018',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2018-01-01', '2018-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-fnf-mosaic'},
#  {'name': '2017',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2017-01-01', '2017-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-fnf-mosaic'},
#  {'name': '2016',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2016-01-01', '2016-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-fnf-mosaic'},
#  {'name': '2015',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2015-01-01', '2015-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-fnf-mosaic'},
#  {'name': 'Most recent',
#   'description': None,
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1998-01-01', '2012-01-01']}]}],
#   'collection_id': 'usgs-gap'},
#  {'name': 'Most recent (2020)',
#   'description': None,
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2020-04-14T00:00:00Z', '2020-04-14T23:59:59Z']}]}],
#   'collection_id': 'mobi'},
#  {'name': 'Most recent',
#   'description': None,
#   'cql': [{'op': '=',
#     'args': [{'property': 'datetime'}, {'timestamp': '2000-02-20'}]}],
#   'collection_id': 'nasadem'},
#  {'name': 'Most recent (2020)',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2020-01-01', '2020-12-31']}]}],
#   'collection_id': 'drcog-lulc'},
#  {'name': '2018',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2018-01-01', '2018-12-31']}]}],
#   'collection_id': 'drcog-lulc'},
#  {'name': 'Most recent',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2010-12-31T00:00:00Z', '2010-12-31T23:59:59Z']}]}],
#   'collection_id': 'hgb'}]

# %%
list(all_mosaics_df.apply(lambda x: x.to_dict() if (('sentinel' not in x['collection_id']) and ('datetime' in str(x['cql']))) else None, axis=1).dropna())

# %% [markdown]
# Queryables Can Be Found Using an endpoint

# %%
import requests
import json

collections_url = "https://planetarycomputer.microsoft.com/api/stac/v1/collections"
response = requests.get(collections_url)
collections_data = response.json()
all_collection_ids = [collection.get('id') for collection in collections_data["collections"]]
config_collection_ids = [config.get('collection_id') for config in configs]
queryables_list = []

# %%
#
for collection_id in valid_collection_ids:
    queryables_url = f"{collections_url}/{collection_id}/queryables"

    try:
        resp = requests.get(queryables_url)
        resp.raise_for_status()
        queryables = resp.json()
        queryables["collection_id"] = collection_id
        queryables_list.append(queryables)
        print(f"Appended queryables for {collection_id}")

    except requests.exceptions.HTTPError as e:
        print(f"Skipping {collection_id}: {e}")
# Out:
# Skipping usgs-gap: 404 Client Error: Not Found for url: https://planetarycomputer.microsoft.com/api/stac/v1/collections/usgs-gap/queryables
# Appended queryables for io-biodiversity
# Appended queryables for mtbs
# Appended queryables for nasadem
# Appended queryables for noaa-c-cap
# Skipping aster: 404 Client Error: Not Found for url: https://planetarycomputer.microsoft.com/api/stac/v1/collections/aster/queryables
# Appended queryables for mobi
# Appended queryables for usda-cdl
# Appended queryables for ms-buildings
# Appended queryables for hgb
# Appended queryables for alos-palsar-mosaic
# Appended queryables for esa-worldcover
# Appended queryables for alos-fnf-mosaic
# Appended queryables for alos-dem
# Appended queryables for hrea
# Appended queryables for sentinel-1-rtc
# Appended queryables for drcog-lulc
# Appended queryables for nrcan-landcover
# Appended queryables for naip
# Appended queryables for sentinel-1-grd
# Appended queryables for esa-cci-lc
# Appended queryables for chloris-biomass
# Skipping sentinel-2: 404 Client Error: Not Found for url: https://planetarycomputer.microsoft.com/api/stac/v1/collections/sentinel-2/queryables
# Appended queryables for jrc-gsw

# %%
queryables_df = pd.DataFrame(queryables_list)

# %%
queryables_df['property_key'] = queryables_df['properties'].apply(lambda x: list(x.keys()))

# %%
queryables_df
# Out:
#                                                   $id    type  \
# 0   https://planetarycomputer.microsoft.com/api/st...  object
# 1   https://planetarycomputer.microsoft.com/api/st...  object
# 2   https://planetarycomputer.microsoft.com/api/st...  object
# 3   https://planetarycomputer.microsoft.com/api/st...  object
# 4   https://planetarycomputer.microsoft.com/api/st...  object
# 5   https://planetarycomputer.microsoft.com/api/st...  object
# 6   https://planetarycomputer.microsoft.com/api/st...  object
# 7   https://planetarycomputer.microsoft.com/api/st...  object
# 8   https://planetarycomputer.microsoft.com/api/st...  object
# 9   https://planetarycomputer.microsoft.com/api/st...  object
# 10  https://planetarycomputer.microsoft.com/api/st...  object
# 11  https://planetarycomputer.microsoft.com/api/st...  object
# 12  https://planetarycomputer.microsoft.com/api/st...  object
# 13  https://planetarycomputer.microsoft.com/api/st...  object
# 14  https://planetarycomputer.microsoft.com/api/st...  object
# 15  https://planetarycomputer.microsoft.com/api/st...  object
# 16  https://planetarycomputer.microsoft.com/api/st...  object
# 17  https://planetarycomputer.microsoft.com/api/st...  object
# 18  https://planetarycomputer.microsoft.com/api/st...  object
# 19  https://planetarycomputer.microsoft.com/api/st...  object
# 20  https://planetarycomputer.microsoft.com/api/st...  object
#
#                title                                  $schema  \
# 0   STAC Queryables.  http://json-schema.org/draft-07/schema#
# 1   STAC Queryables.  http://json-schema.org/draft-07/schema#
# 2   STAC Queryables.  http://json-schema.org/draft-07/schema#
# 3   STAC Queryables.  http://json-schema.org/draft-07/schema#
# 4   STAC Queryables.  http://json-schema.org/draft-07/schema#
# 5   STAC Queryables.  http://json-schema.org/draft-07/schema#
# 6   STAC Queryables.  http://json-schema.org/draft-07/schema#
# 7   STAC Queryables.  http://json-schema.org/draft-07/schema#
# 8   STAC Queryables.  http://json-schema.org/draft-07/schema#
# 9   STAC Queryables.  http://json-schema.org/draft-07/schema#
# 10  STAC Queryables.  http://json-schema.org/draft-07/schema#
# 11  STAC Queryables.  http://json-schema.org/draft-07/schema#
# 12  STAC Queryables.  http://json-schema.org/draft-07/schema#
# 13  STAC Queryables.  http://json-schema.org/draft-07/schema#
# 14  STAC Queryables.  http://json-schema.org/draft-07/schema#
# 15  STAC Queryables.  http://json-schema.org/draft-07/schema#
# 16  STAC Queryables.  http://json-schema.org/draft-07/schema#
# 17  STAC Queryables.  http://json-schema.org/draft-07/schema#
# 18  STAC Queryables.  http://json-schema.org/draft-07/schema#
# 19  STAC Queryables.  http://json-schema.org/draft-07/schema#
# 20  STAC Queryables.  http://json-schema.org/draft-07/schema#
#
#                                            properties       collection_id  \
# 0   {'id': {'$ref': 'https://schemas.stacspec.org/...     io-biodiversity
# 1   {'id': {'$ref': 'https://schemas.stacspec.org/...                mtbs
# 2   {'id': {'$ref': 'https://schemas.stacspec.org/...             nasadem
# 3   {'id': {'$ref': 'https://schemas.stacspec.org/...          noaa-c-cap
# 4   {'id': {'$ref': 'https://schemas.stacspec.org/...                mobi
# 5   {'id': {'$ref': 'https://schemas.stacspec.org/...            usda-cdl
# 6   {'id': {'$ref': 'https://schemas.stacspec.org/...        ms-buildings
# 7   {'id': {'$ref': 'https://schemas.stacspec.org/...                 hgb
# 8   {'cf': {'type': 'string'}, 'id': {'$ref': 'htt...  alos-palsar-mosaic
# 9   {'id': {'$ref': 'https://schemas.stacspec.org/...      esa-worldcover
# 10  {'id': {'$ref': 'https://schemas.stacspec.org/...     alos-fnf-mosaic
# 11  {'id': {'$ref': 'https://schemas.stacspec.org/...            alos-dem
# 12  {'id': {'$ref': 'https://schemas.stacspec.org/...                hrea
# 13  {'id': {'$ref': 'https://schemas.stacspec.org/...      sentinel-1-rtc
# 14  {'id': {'$ref': 'https://schemas.stacspec.org/...          drcog-lulc
# 15  {'id': {'$ref': 'https://schemas.stacspec.org/...     nrcan-landcover
# 16  {'id': {'$ref': 'https://schemas.stacspec.org/...                naip
# 17  {'id': {'$ref': 'https://schemas.stacspec.org/...      sentinel-1-grd
# 18  {'id': {'$ref': 'https://schemas.stacspec.org/...          esa-cci-lc
# 19  {'id': {'$ref': 'https://schemas.stacspec.org/...     chloris-biomass
# 20  {'id': {'$ref': 'https://schemas.stacspec.org/...             jrc-gsw
#
#                                         property_keys  \
# 0   [id, datetime, geometry, end_datetime, start_d...
# 1   [id, datetime, geometry, end_datetime, start_d...
# 2   [id, datetime, geometry, proj:bbox, proj:epsg,...
# 3   [id, datetime, geometry, end_datetime, start_d...
# 4   [id, datetime, geometry, end_datetime, start_d...
# 5   [id, datetime, geometry, proj:epsg, proj:shape...
# 6   [id, datetime, geometry, end_datetime, start_d...
# 7   [id, datetime, geometry, end_datetime, start_d...
# 8   [cf, id, gsd, title, datetime, geometry, platf...
# 9   [id, created, mission, datetime, geometry, pro...
# 10  [id, gsd, title, datetime, geometry, proj:bbox...
# 11  [id, gsd, datetime, geometry, proj:epsg, proj:...
# 12  [id, datetime, geometry, proj:epsg, end_dateti...
# 13  [id, datetime, geometry, platform, s1:shape, p...
# 14  [id, created, mission, datetime, geometry, pro...
# 15  [id, datetime, geometry, end_datetime, start_d...
# 16  [id, gsd, datetime, geometry, naip:year, proj:...
# 17  [id, datetime, geometry, platform, s1:shape, e...
# 18  [id, title, created, datetime, geometry, proj:...
# 19  [id, datetime, geometry, end_datetime, start_d...
# 20  [id, sci:doi, datetime, geometry, proj:bbox, p...
#
#                                          property_key
# 0   [id, datetime, geometry, end_datetime, start_d...
# 1   [id, datetime, geometry, end_datetime, start_d...
# 2   [id, datetime, geometry, proj:bbox, proj:epsg,...
# 3   [id, datetime, geometry, end_datetime, start_d...
# 4   [id, datetime, geometry, end_datetime, start_d...
# 5   [id, datetime, geometry, proj:epsg, proj:shape...
# 6   [id, datetime, geometry, end_datetime, start_d...
# 7   [id, datetime, geometry, end_datetime, start_d...
# 8   [cf, id, gsd, title, datetime, geometry, platf...
# 9   [id, created, mission, datetime, geometry, pro...
# 10  [id, gsd, title, datetime, geometry, proj:bbox...
# 11  [id, gsd, datetime, geometry, proj:epsg, proj:...
# 12  [id, datetime, geometry, proj:epsg, end_dateti...
# 13  [id, datetime, geometry, platform, s1:shape, p...
# 14  [id, created, mission, datetime, geometry, pro...
# 15  [id, datetime, geometry, end_datetime, start_d...
# 16  [id, gsd, datetime, geometry, naip:year, proj:...
# 17  [id, datetime, geometry, platform, s1:shape, e...
# 18  [id, title, created, datetime, geometry, proj:...
# 19  [id, datetime, geometry, end_datetime, start_d...
# 20  [id, sci:doi, datetime, geometry, proj:bbox, p...

# %%
all_keys = set().union(*queryables_df['properties'].apply(lambda prop: [key for nested in prop.values() for key in nested.keys()]))

# %%
naip_queryables=list(queryables_df[queryables_df['collection_id']=='naip']['properties'])[0]

naip_queryables.keys()
# Out:
# dict_keys(['id', 'gsd', 'datetime', 'geometry', 'naip:year', 'proj:bbox', 'proj:epsg', 'naip:state', 'proj:shape', 'end_datetime', 'proj:transform', 'start_datetime'])

# %%
rows = []
for _, row in queryables_df.iterrows():
    collection_id = row['collection_id']
    for prop_name, definition in row['properties'].items():
        rows.append({
            'collection_id': collection_id,
            'property_name': prop_name,
            'definition': definition
        })

properties_df = pd.DataFrame(rows)

# %%
definitions_df = properties_df.map(str).groupby('property_name').agg(lambda x: list(set(x))).reset_index()[['property_name','definition']]\
    .explode('definition').map(lambda x: eval(x) if '{' in x else x)\
    .apply(lambda x: {'property_name':x.get('property_name'), 'definition':list(x.get('definition').items())}, axis=1)\
    .apply(pd.Series).explode('definition')

definitions_df['']

# %%
missing_queryable_definitions={'example', 'examples', 'items', 'pattern', 'integer', 'type': 'sar:looks_range'}

# %%
definitions_df['key']=definitions_df['definition'].apply(lambda x: str(x[0]))
definitions_df['value']=definitions_df['definition'].apply(lambda x: str(x[1]))
pd.DataFrame(definitions_df.groupby(['key','value'])['property_name'].agg(list).head(90).tail(30))
# Out:
#                                                                      property_name
# key   value
# title Orbit Source                                               [s1:orbit_source]
#       Orbit State                                                [sat:orbit_state]
#       Pixel spacing azimuth (m)                        [sar:pixel_spacing_azimuth]
#       Pixel spacing range (m)                            [sar:pixel_spacing_range]
#       Platform                                                [platform, platform]
#       Platform Designation                 [sat:platform_international_designator]
#       Polarization number                         [palsar:number_of_polarizations]
#       Polarizations                                            [sar:polarizations]
#       Product Timeliness                                   [s1:product_timeliness]
#       Product Version                                         [esa_cci_lc:version]
#       Product type                                              [sar:product_type]
#       Proposed Data Citation                                        [sci:citation]
#       Relative Orbit                                          [sat:relative_orbit]
#       Resolution                                                   [s1:resolution]
#       Resolution azimuth (m)                              [sar:resolution_azimuth]
#       Resolution range (m)                                  [sar:resolution_range]
#       Shape                                                           [proj:shape]
#       Slice Number                                               [s1:slice_number]
#       Start datetime                                              [start_datetime]
#       State                                                           [naip:state]
#       Tile                                                       [esa_cci_lc:tile]
#       Tile ID                                        [esa_worldcover:product_tile]
#       Total Slices                                               [s1:total_slices]
#       Transform                                                   [proj:transform]
#       Year                                                             [naip:year]
# type  ['integer', 'null']                                              [proj:epsg]
#       array                      [instruments, proj:bbox, proj:shape, proj:tran...
#       integer                                 [sar:looks_azimuth, sar:looks_range]
#       number                     [gsd, sar:center_frequency, sar:looks_equivale...
#       string                     [cf, constellation, created, datetime, descrip...

# %%
queryable_properties_df = queryables_df[['collection_id','property_key']].explode('property_key')\
    .groupby('property_key').agg(list).reset_index()

queryable_properties_df['collection_count']=queryable_properties_df['collection_id'].apply(lambda x: len(set(x)))

queryable_properties_df.sort_values(by='collection_count', ascending=False)
# Out:
#                              property_key  \
# 11                                     id
# 51                         start_datetime
# 3                                datetime
# 5                            end_datetime
# 9                                geometry
# 20                              proj:epsg
# 21                             proj:shape
# 22                         proj:transform
# 19                              proj:bbox
# 10                                    gsd
# 12                            instruments
# 4                             description
# 42                       sar:product_type
# 52                                  title
# 41                      sar:polarizations
# 33                     sar:frequency_band
# 38              sar:observation_direction
# 46                        sat:orbit_state
# 18                               platform
# 2                                 created
# 34                    sar:instrument_mode
# 35                      sar:looks_azimuth
# 32                   sar:center_frequency
# 40                sar:pixel_spacing_range
# 36            sar:looks_equivalent_number
# 37                        sar:looks_range
# 39              sar:pixel_spacing_azimuth
# 30                        s1:slice_number
# 31                        s1:total_slices
# 27                  s1:product_timeliness
# 29                               s1:shape
# 45                     sat:absolute_orbit
# 1                           constellation
# 26                    s1:processing_level
# 25                        s1:orbit_source
# 24         s1:instrument_configuration_ID
# 23                         s1:datatake_id
# 44                   sar:resolution_range
# 47  sat:platform_international_designator
# 48                     sat:relative_orbit
# 13                                mission
# 43                 sar:resolution_azimuth
# 49                           sci:citation
# 50                                sci:doi
# 0                                      cf
# 28                          s1:resolution
# 17         palsar:number_of_polarizations
# 16                     palsar:beam_number
# 15                              naip:year
# 14                             naip:state
# 8             esa_worldcover:product_tile
# 7                      esa_cci_lc:version
# 6                         esa_cci_lc:tile
# 53                          usda_cdl:type
#
#                                         collection_id  collection_count
# 11  [io-biodiversity, mtbs, nasadem, noaa-c-cap, m...                21
# 51  [io-biodiversity, mtbs, nasadem, noaa-c-cap, m...                21
# 3   [io-biodiversity, mtbs, nasadem, noaa-c-cap, m...                21
# 5   [io-biodiversity, mtbs, nasadem, noaa-c-cap, m...                21
# 9   [io-biodiversity, mtbs, nasadem, noaa-c-cap, m...                21
# 20  [nasadem, usda-cdl, alos-palsar-mosaic, esa-wo...                12
# 21  [nasadem, usda-cdl, alos-palsar-mosaic, alos-f...                10
# 22  [nasadem, usda-cdl, alos-palsar-mosaic, alos-f...                10
# 19  [nasadem, alos-palsar-mosaic, alos-fnf-mosaic,...                 6
# 10  [alos-palsar-mosaic, alos-fnf-mosaic, alos-dem...                 4
# 12  [alos-palsar-mosaic, esa-worldcover, alos-fnf-...                 4
# 4   [alos-palsar-mosaic, esa-worldcover, alos-fnf-...                 4
# 42  [alos-palsar-mosaic, sentinel-1-rtc, sentinel-...                 3
# 52  [alos-palsar-mosaic, alos-fnf-mosaic, esa-cci-lc]                 3
# 41  [alos-palsar-mosaic, sentinel-1-rtc, sentinel-...                 3
# 33  [alos-palsar-mosaic, sentinel-1-rtc, sentinel-...                 3
# 38  [alos-palsar-mosaic, sentinel-1-rtc, sentinel-...                 3
# 46  [alos-palsar-mosaic, sentinel-1-rtc, sentinel-...                 3
# 18  [alos-palsar-mosaic, sentinel-1-rtc, sentinel-...                 3
# 2            [esa-worldcover, drcog-lulc, esa-cci-lc]                 3
# 34  [alos-palsar-mosaic, sentinel-1-rtc, sentinel-...                 3
# 35                   [sentinel-1-rtc, sentinel-1-grd]                 2
# 32                   [sentinel-1-rtc, sentinel-1-grd]                 2
# 40                   [sentinel-1-rtc, sentinel-1-grd]                 2
# 36                   [sentinel-1-rtc, sentinel-1-grd]                 2
# 37                   [sentinel-1-rtc, sentinel-1-grd]                 2
# 39                   [sentinel-1-rtc, sentinel-1-grd]                 2
# 30                   [sentinel-1-rtc, sentinel-1-grd]                 2
# 31                   [sentinel-1-rtc, sentinel-1-grd]                 2
# 27                   [sentinel-1-rtc, sentinel-1-grd]                 2
# 29                   [sentinel-1-rtc, sentinel-1-grd]                 2
# 45                   [sentinel-1-rtc, sentinel-1-grd]                 2
# 1                    [sentinel-1-rtc, sentinel-1-grd]                 2
# 26                   [sentinel-1-rtc, sentinel-1-grd]                 2
# 25                   [sentinel-1-rtc, sentinel-1-grd]                 2
# 24                   [sentinel-1-rtc, sentinel-1-grd]                 2
# 23                   [sentinel-1-rtc, sentinel-1-grd]                 2
# 44                   [sentinel-1-rtc, sentinel-1-grd]                 2
# 47                   [sentinel-1-rtc, sentinel-1-grd]                 2
# 48                   [sentinel-1-rtc, sentinel-1-grd]                 2
# 13                       [esa-worldcover, drcog-lulc]                 2
# 43                   [sentinel-1-rtc, sentinel-1-grd]                 2
# 49                                          [jrc-gsw]                 1
# 50                                          [jrc-gsw]                 1
# 0                                [alos-palsar-mosaic]                 1
# 28                                   [sentinel-1-grd]                 1
# 17                               [alos-palsar-mosaic]                 1
# 16                               [alos-palsar-mosaic]                 1
# 15                                             [naip]                 1
# 14                                             [naip]                 1
# 8                                    [esa-worldcover]                 1
# 7                                        [esa-cci-lc]                 1
# 6                                        [esa-cci-lc]                 1
# 53                                         [usda-cdl]                 1

# %% [markdown]
# All type, title, and $schema are the same

# %%
{k: set(queryables_df[k]) for k in ['type', 'title', '$schema']}
# Out:
# {'type': {'object'},
#  'title': {'STAC Queryables.'},
#  '$schema': {'http://json-schema.org/draft-07/schema#'}}
