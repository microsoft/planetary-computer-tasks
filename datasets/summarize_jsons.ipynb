# %%
from pathlib import Path
import json
import pandas as pd

# %%
datasets_path = Path(".")

config_paths = datasets_path.rglob("*/collection/config.json")

configs = []

for path in config_paths:
    try:
        with open(path, "r") as f:
            config_data = json.load(f)

        collection_id = path.parent.parent.name
        config_data['collection_id'] = collection_id

        configs.append(config_data)
    except Exception as e:
        print(f"Error loading {path}: {e}")

print(f"Loaded {len(configs)} config.json files.")
# Out:
# Loaded 24 config.json files.

# %% [markdown]
# Every collection has a mosaic_info and render_config in config.json

# %%
all_key_sets = [set(config.keys()) for config in configs]
all_keys = set().union(*all_key_sets)
print(all_keys)
# Out:
# {'mosaic_info', 'render_config'}

# %%
all_mosaic_info_key_sets = [set(config.get('mosaic_info',{}).keys()) for config in configs]
all_mosaic_info_keys = set().union(*all_mosaic_info_key_sets)
print(all_mosaic_info_keys)
# Out:
# {'default_location', 'mosaics', 'animation_hint', 'render_options', 'default_custom_query'}

# %%
all_mosaic_key_sets = [
    set(mosaic.keys())
    for config in configs
    for mosaic in config.get('mosaic_info',{}).get('mosaics',[])
    ]

mosaic_key_union = set().union(*all_mosaic_key_sets)

print(mosaic_key_union)
# Out:
# {'name', 'description', 'cql'}

# %%
all_mosaics = [
    {**mosaic, "collection_id": config['collection_id']}
    for config in configs
    for mosaic in config.get('mosaic_info',{}).get('mosaics',[])
]

all_mosaics_df = pd.DataFrame(all_mosaics)

# %% [markdown]
# Commonly, a mosaic includes a cql search based on the properties of datetime, eo:cloud_cover, id, sar:polarizations, or usda_cdl:type

# %%
from collections import Counter

set(all_mosaics_df['cql'].explode().dropna().apply(lambda x: x.get('args')[0]).apply(str))
# Out:
# {"{'property': 'datetime'}",
#  "{'property': 'eo:cloud_cover'}",
#  "{'property': 'id'}",
#  "{'property': 'sar:polarizations'}",
#  "{'property': 'usda_cdl:type'}"}

# %%
list(all_mosaics_df.apply(lambda x: x.to_dict() if (('sentinel' not in x['collection_id']) and ('datetime' in str(x['cql']))) else None, axis=1).dropna())
# Out:
# [{'name': '2020',
#   'description': '2020 Biodiversity Intactness',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2020-01-01T00:00:00Z', '2020-12-31T23:59:59Z']}]}],
#   'collection_id': 'io-biodiversity'},
#  {'name': '2019',
#   'description': '2019 Biodiversity Intactness',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2019-01-01T00:00:00Z', '2019-12-31T23:59:59Z']}]}],
#   'collection_id': 'io-biodiversity'},
#  {'name': '2018',
#   'description': '2018 Biodiversity Intactness',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2018-01-01T00:00:00Z', '2018-12-31T23:59:59Z']}]}],
#   'collection_id': 'io-biodiversity'},
#  {'name': '2017',
#   'description': '2017 Biodiversity Intactness',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2017-01-01T00:00:00Z', '2017-12-31T23:59:59Z']}]}],
#   'collection_id': 'io-biodiversity'},
#  {'name': 'Most recent',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2016-12-07T00:00:00Z', '2016-12-07T23:59:59Z']}]}],
#   'collection_id': 'alos-dem'},
#  {'name': '2019',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2018-08-01', '2019-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2018',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2017-08-01', '2018-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2017',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2016-08-01', '2017-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2016',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2015-08-01', '2016-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2015',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2014-08-01', '2015-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2014',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2013-08-01', '2014-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2013',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2012-08-01', '2013-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2012',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2011-08-01', '2012-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2011',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2010-08-01', '2011-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2010',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2009-08-01', '2010-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2009',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2008-08-01', '2009-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2008',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2007-08-01', '2008-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2007',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2006-08-01', '2007-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2006',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2005-08-01', '2006-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2005',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2004-08-01', '2005-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2004',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2003-08-01', '2004-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2003',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2002-08-01', '2003-01-01']}]}],
#   'collection_id': 'chloris-biomass'},
#  {'name': '2023',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2023-01-01', '2023-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2022',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2022-01-01', '2022-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2021',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2021-01-01', '2021-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2020',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2020-01-01', '2020-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2019',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2019-01-01', '2019-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2018',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2018-01-01', '2018-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2017',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2017-01-01', '2017-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2016',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2016-01-01', '2016-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2015',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2015-01-01', '2015-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2014',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2014-01-01', '2014-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2013',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2013-01-01', '2013-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2012',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2012-01-01', '2012-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2011',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2011-01-01', '2011-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': '2010',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2010-01-01', '2010-12-31T23:59:59Z']}]}],
#   'collection_id': 'naip'},
#  {'name': 'Most recent',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2020-06-06T00:00:00Z', '2020-06-06T23:59:59Z']}]}],
#   'collection_id': 'jrc-gsw'},
#  {'name': 'Most recent (2020)',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2020-01-01', '2020-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2019',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2019-01-01', '2019-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2018',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2018-01-01', '2018-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2017',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2017-01-01', '2017-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2016',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2016-01-01', '2016-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2015',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2015-01-01', '2015-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2014',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2014-01-01', '2014-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2013',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2013-01-01', '2013-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2012',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2012-01-01', '2012-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2011',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2011-01-01', '2011-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2010',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2010-01-01', '2010-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2009',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2009-01-01', '2009-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2008',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2008-01-01', '2008-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2007',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2007-01-01', '2007-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2006',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2006-01-01', '2006-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2005',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2005-01-01', '2005-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2004',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2004-01-01', '2004-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2003',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2003-01-01', '2003-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2002',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2002-01-01', '2002-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2001',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2001-01-01', '2001-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2000',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2000-01-01', '2000-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '1999',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1999-01-01', '1999-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '1998',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1998-01-01', '1998-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '1997',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1997-01-01', '1997-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '1996',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1996-01-01', '1996-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '1995',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1995-01-01', '1995-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '1994',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1994-01-01', '1994-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '1993',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1993-01-01', '1993-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '1992',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1992-01-01', '1992-12-31']}]}],
#   'collection_id': 'esa-cci-lc'},
#  {'name': '2021 (version 2)',
#   'description': '2021 Land Cover',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2021-01-01T23:59:59Z', '2021-12-31T23:59:59Z']}]}],
#   'collection_id': 'esa-worldcover'},
#  {'name': '2020 (version 1)',
#   'description': '2020 Land Cover',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2020-01-01T23:59:59Z', '2020-12-31T23:59:59Z']}]}],
#   'collection_id': 'esa-worldcover'},
#  {'name': 'Most recent (2019)',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2019-01-01', '2019-12-31']}]}],
#   'collection_id': 'hrea'},
#  {'name': '2018',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2018-01-01', '2018-12-31']}]}],
#   'collection_id': 'hrea'},
#  {'name': '2017',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2017-01-01', '2017-12-31']}]}],
#   'collection_id': 'hrea'},
#  {'name': '2016',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2016-01-01', '2016-12-31']}]}],
#   'collection_id': 'hrea'},
#  {'name': '2015',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2015-01-01', '2015-12-31']}]}],
#   'collection_id': 'hrea'},
#  {'name': '2014',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2014-01-01', '2014-12-31']}]}],
#   'collection_id': 'hrea'},
#  {'name': '2013',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2013-01-01', '2013-12-31']}]}],
#   'collection_id': 'hrea'},
#  {'name': '2012',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2012-01-01', '2012-12-31']}]}],
#   'collection_id': 'hrea'},
#  {'name': 'Most recent',
#   'description': 'Most recent Land Use/Land Cover',
#   'cql': [{'op': '>=',
#     'args': [{'property': 'datetime'}, {'timestamp': '2015-01-01'}]}],
#   'collection_id': 'nrcan-landcover'},
#  {'name': 'All years',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1984-12-31', '2018-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': 'Most recent (2018)',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2018-01-01', '2018-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2017',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2017-01-01', '2017-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2016',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2016-01-01', '2016-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2015',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2015-01-01', '2015-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2014',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2014-01-01', '2014-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2013',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2013-01-01', '2013-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2012',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2012-01-01', '2012-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2011',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2011-01-01', '2011-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2010',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2010-01-01', '2010-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2009',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2009-01-01', '2009-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2008',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2008-01-01', '2008-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2007',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2007-01-01', '2007-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2006',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2006-01-01', '2006-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2005',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2005-01-01', '2005-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2004',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2004-01-01', '2004-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2003',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2003-01-01', '2003-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2002',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2002-01-01', '2002-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2001',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2001-01-01', '2001-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2000',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2000-01-01', '2000-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1999',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1999-01-01', '1999-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1998',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1998-01-01', '1998-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1997',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1997-01-01', '1997-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1996',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1996-01-01', '1996-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1995',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1995-01-01', '1995-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1994',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1994-01-01', '1994-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1993',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1993-01-01', '1993-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1992',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1992-01-01', '1992-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1991',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1991-01-01', '1991-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1990',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1990-01-01', '1990-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1989',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1989-01-01', '1989-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1988',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1988-01-01', '1988-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1987',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1987-01-01', '1987-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1986',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1986-01-01', '1986-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1985',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1985-01-01', '1985-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '1984',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1984-12-31', '1984-12-31']}]}],
#   'collection_id': 'mtbs'},
#  {'name': '2020',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2020-01-01', '2020-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-palsar-mosaic'},
#  {'name': '2019',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2019-01-01', '2019-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-palsar-mosaic'},
#  {'name': '2018',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2018-01-01', '2018-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-palsar-mosaic'},
#  {'name': '2017',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2017-01-01', '2017-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-palsar-mosaic'},
#  {'name': '2016',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2016-01-01', '2016-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-palsar-mosaic'},
#  {'name': '2015',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2015-01-01', '2015-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-palsar-mosaic'},
#  {'name': '2020',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2020-01-01', '2020-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-fnf-mosaic'},
#  {'name': '2019',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2019-01-01', '2019-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-fnf-mosaic'},
#  {'name': '2018',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2018-01-01', '2018-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-fnf-mosaic'},
#  {'name': '2017',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2017-01-01', '2017-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-fnf-mosaic'},
#  {'name': '2016',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2016-01-01', '2016-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-fnf-mosaic'},
#  {'name': '2015',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2015-01-01', '2015-12-31T23:59:59Z']}]}],
#   'collection_id': 'alos-fnf-mosaic'},
#  {'name': 'Most recent',
#   'description': None,
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['1998-01-01', '2012-01-01']}]}],
#   'collection_id': 'usgs-gap'},
#  {'name': 'Most recent (2020)',
#   'description': None,
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2020-04-14T00:00:00Z', '2020-04-14T23:59:59Z']}]}],
#   'collection_id': 'mobi'},
#  {'name': 'Most recent',
#   'description': None,
#   'cql': [{'op': '=',
#     'args': [{'property': 'datetime'}, {'timestamp': '2000-02-20'}]}],
#   'collection_id': 'nasadem'},
#  {'name': 'Most recent (2020)',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2020-01-01', '2020-12-31']}]}],
#   'collection_id': 'drcog-lulc'},
#  {'name': '2018',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2018-01-01', '2018-12-31']}]}],
#   'collection_id': 'drcog-lulc'},
#  {'name': 'Most recent',
#   'description': '',
#   'cql': [{'op': 'anyinteracts',
#     'args': [{'property': 'datetime'},
#      {'interval': ['2010-12-31T00:00:00Z', '2010-12-31T23:59:59Z']}]}],
#   'collection_id': 'hgb'}]

# %%
list(all_mosaics_df.apply(lambda x: x.to_dict() if (('sentinel' not in x['collection_id']) and ('datetime' in str(x['cql']))) else None, axis=1).dropna())
